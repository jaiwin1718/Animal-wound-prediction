# %% [markdown]
# <a href="https://colab.research.google.com/github/Mathii0402/Animal-Wound-Prediction/blob/main/Wound_deduction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **ANIMAL WOUND DEDUCTION USING YOLOV5**

# %% [markdown]
# How YOLO5 works?
# ![Screenshot 2022-05-22 231546.png](data:image/png;base64,...)

# %%
# !git clone https://github.com/ultralytics/yolov5  
# %cd yolov5
# %pip install -qr requirements.txt  

import torch
import utils
display = utils.notebook_init()
# Out:
# YOLOv5 🚀 v6.1-214-g541a5b7 Python-3.7.13 torch-1.11.0+cu113 CUDA:0 (Tesla T4, 15110MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 38.7/78.2 GB disk)

# %% [markdown]
# Unzipping custom  data set

# %%
# !unzip -q /content/project.zip -d ../

# %% [markdown]
# **Training using YOLOV5**

# %%
# !python train.py --img 1280 --batch 16 --epochs 150 --data /content/yolov5/data/wound.yaml --weights yolov5s.pt --cache
# Out:
# train: weights=yolov5s.pt, cfg=, data=/content/yolov5/data/wound.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=150, batch_size=16, imgsz=1280, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.1-214-g541a5b7 Python-3.7.13 torch-1.11.0+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# ...

# %%
# !python detect.py --weights runs/train/exp/weights/best.pt --img 1280 --conf 0.25 --source ../predimages/h.jpg 
display.Image(filename='../predimages/h.jpg', width=600)
# Out:
# detect: weights=['runs/train/exp/weights/best.pt'], source=../predimages/h.jpg, data=data/coco128.yaml, imgsz=[1280, 1280], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-214-g541a5b7 Python-3.7.13 torch-1.11.0+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model summary: 213 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/predimages/h.jpg: 864x1280 Done. (0.025s)
# Speed: 1.2ms pre-process, 24.5ms inference, 0.3ms NMS per image at shape (1, 3, 1280, 1280)
# Results saved to runs/detect/exp16

# %%
display.Image(filename='runs/detect/exp16/h.jpg', width=600)

# %% [markdown]
# Animal is healthy there is no bounding box saying its wounded. hence it is helthy.
